# %%
# prepare data
# !python main.py --prepare
# Out:
# Preparing data...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743276334.925834 23937806 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2
# Processing KTH dataset...
# Download
# ...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1743276335.025120 23937923 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1743276335.039491 23937924 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# https://www.csc.kth.se/cvap/actions/boxing.zip: 100%|█| 185M/185M [04:58<00:00,
# Extracting boxing.zip...
# Downloaded and extracted boxing videos.
# ...
# https://www.csc.kth.se/cvap/actions/handclapping.zip: 100%|█| 169M/169M [03:13<0
# Extracting handclapping.zip...
# ...

# %%
# train model
# !python main.py --train --epochs 60 --batch-size 32 --learning-rate 0.0001
# Out:
# Training action recognition model with 60 epochs...
# Dataset loaded: X_train shape = (255, 30, 132)
# Classes: ['boxing', 'handclapping', 'handwaving', 'walking']
# Using device: cpu
# ...
# Evaluating: 100%|█████████████████████████████████| 3/3 [00:00<00:00, 65.10it/s]
# Test Accuracy: 0.9250
#
# Class-wise Accuracy:
#   boxing: 0.9000 (18/20)
#   handclapping: 0.9000 (18/20)
#   handwaving: 0.9000 (18/20)
#   walking: 1.0000 (20/20)
#
# Confusion Matrix:
# [[18  0  0  2]
#  [ 0 18  2  0]
#  [ 0  2 18  0]
#  [ 0  0  0 20]]
# Model training complete! Test accuracy: 0.9250
# Model trained and saved to: models/action_classifier/action_classifier_batch32_lr0.0001_epochs60/best_model_acc.pth

# %%
# run game
# !python main.py --play --difficulty hard --model-path "models/action_classifier/action_classifier_batch32_lr0.0001_epochs60/best_model_loss.pth"
